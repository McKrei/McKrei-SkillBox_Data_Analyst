# %% [markdown]
# 1. Вы провели рекламную кампанию в соцсетях стоимостью 65 300 рублей. Она привлекла вам 228 новых клиентов. Создайте переменные для стоимости и количества новых клиентов. Используя созданные переменные, посчитайте значение CPA (cost per acquisition), которое рассчитывается как отношение стоимости кампании к количеству привлечённых клиентов. Выведите результат на экран.

# %%
# Дополните код, чтобы создать переменные, и расчитайте CPA

cost = 65300
new_clients = 228
cpa = int(cost/new_clients)
print(f'{cpa = } рублей.')
# Out:
# cpa = 286 рублей.

# %%
# Допишите вывод итогового значения на экран

# %% [markdown]
# 2. В рекламе модного фитнес-центра вы увидели, что у них есть бассейн длиной 25 метров, шириной 15 метров и глубиной 2,5 метра. Вы стали размышлять, как долго обходить такой бассейн кругом, как много воды в него поместится и всё в таком духе. Создайте соответствующие переменные и посчитайте площадь поверхности бассейна, периметр поверхности и объём. Выведите все три параметра на экран, чтобы их легко можно было различить.

# %%
# Дополните код
# Переменные из условия задачи:
lenght = 25
width = 15
depth = 2.5

# %%
# Дополните код
# Рассчитайте площадь, периметр и объём (для объёма придумайте переменную самостоятельно)

area = lenght * width
perimeter = area * 2
volume = area * depth

# %%
# Дополните код
# Выведите на экран полученный результат для каждого из параметров

print("Площадь поверхности", area, "квадратных метров")
print(f'{perimeter = } m; {volume = } m3')
# Out:
# Площадь поверхности 375 квадратных метров
# perimeter = 750 m; volume = 937.5 m3

# %% [markdown]
# 3. Случилась неприятность: вы заболели. Врач прописал вам принимать таблетки по одной штуке три раза в день в течение пяти дней. Создайте необходимые переменные и рассчитайте (и сохраните в переменную), сколько таблеток вам понадобится на курс. Выведите получившееся значение на экран с пояснениями, например так: «Мне потребуется ххххх таблеток».

# %%
# Дополните код
# Расчёт курса лечения
days = 5
count_in_day = 3
count_tablet = 1
sum_tablet = days * count_in_day * count_tablet

# %%
# Дополните код
# Вывод результата на экран с пояснениями
print(f'Мне потребуется {sum_tablet} таблеток')
# Out:
# Мне потребуется 15 таблеток

# %% [markdown]
# В аптеке необходимое лекарство продаётся в упаковках по 12 таблеток. Вы купили две упаковки. Рассчитайте, сколько таблеток у вас останется после курса. Выведите полученное значение на экран также с пояснениями.

# %%
# Дополните код
# Расчёт остатка таблеток
pills_in_pack = 12
value = pills_in_pack * 2 - sum_tablet

# %%
# Дополните код
# Вывод результата на экран с пояснениями
print(f'После курса у меня останеться {value} табл.')
# Out:
# После курса у меня останеться 9 табл.

# %% [markdown]
# 4. Вы ехали 75 километров, на это у вас ушло два часа. Рассчитайте среднюю скорость, с которой вы ехали, сохраните её в переменную. Выведите на печать тип данных, к которому относится полученная переменная.

# %%
# Дополните код
# Расчёт средней скорости
distance = 75
time = 2
speed = distance/time

# %%
# Вывод на печать типа данных переменной

print(type(speed))
# Out:
# <class 'float'>
